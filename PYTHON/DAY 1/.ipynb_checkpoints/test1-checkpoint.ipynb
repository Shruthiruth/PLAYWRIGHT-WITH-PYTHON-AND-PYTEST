# %%
print('new')
# Out:
# new

# %%
print('sorry'
# Out:
# sorry

# %%
print('helo world')
# Out:
# helo world

# %%
7/5
# Out:
# 1.4

# %%
50%5
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
2 + 10 * 10 + 3
# Out:
# 105
