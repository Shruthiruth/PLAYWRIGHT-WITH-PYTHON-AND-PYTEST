# %%
'hello'
# Out:
# 'hello'

# %%
saakshi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 saakshi
#
# NameError: name 'saakshi' is not defined

# %%
"saakshi"
# Out:
# 'saakshi'

# %%
"saakshisree.R"
# Out:
# 'saakshisree.R'

# %%
'saakshisree.R ''and s'
# Out:
# 'saakshisree.R and s'

# %%
'1'
# Out:
# '1'

# %%
'1'
'2'
# Out:
# '2'

# %%
print('1')
print('2')
# Out:
# 1
# 2

# %%
print('saakshisree and shruthika')
# Out:
# saakshisree and shruthika

# %%
len('heelo')
# Out:
# 5

# %%
len("saakshisree and shruthika, rajan babu.")
# Out:
# 38

# %%
mystring='saakshi'
mystring[0]
# Out:
# 's'

# %%
mystring[-1]
# Out:
# 'i'

# %%
mystring[3]
# Out:
# 'k'

# %%
mystring[0:2]
# Out:
# 'sa'

# %%
mystring[0:7:2]
# Out:
# 'sasi'

# %%
mystring[::-1]
# Out:
# 'ihskaas'

# %%
mystring[::2]
# Out:
# 'sasi'

# %%
'p'+mystring
# Out:
# 'psaakshi'

# %%
x= ' hello ' 
s = ' beautiful girl '

# %%
x + mystring + s
# Out:
# ' hello saakshi beautiful girl '

# %%
'2'+'2'
# Out:
# '22'

# %%
'2'*5
# Out:
# '22222'

# %%
x.upper()
# Out:
# ' HELLO '

# %%
x.
# Out:
#   Cell In[28], line 1
#     x.
#       ^
# SyntaxError: invalid syntax

# %%
x.split()
# Out:
# ['hello']

# %%
x='sh r i ok'

# %%
x.split()
# Out:
# ['sh', 'r', 'i', 'ok']

# %%
print('the {} {} {} ' .format('fox','yellow','quic'))
# Out:
# the fox yellow quic

# %%
result=100/700
result
# Out:
# 0.14285714285714285

# %%
print('the result was {R}'.format(R=result))
# Out:
# the result was 0.14285714285714285

# %%
name='shruthi'
print(f'helo,his nemae is {name}')
# Out:
# helo,his nemae is shruthi

# %%
my_list=[200,'shruhi',233.42]

# %%
print(my_list)
len(my_list)
# Out:
# [200, 'shruhi', 233.42]
# 3

# %%
my_list[0]=344
print(my_list)
# Out:
# [344, 'shruhi', 233.42]

# %%
my_list.append('3444')

# %%
print(my_list)
# Out:
# [344, 'shruhi', 233.42, '3444']

# %%
my_list.pop()
print(my_list)
# Out:
# [344, 'shruhi', 233.42]
