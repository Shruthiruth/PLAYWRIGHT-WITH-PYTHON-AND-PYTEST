# %%
t=(1,'one',3.0)
print(t)
type(t)
# Out:
# (1, 'one', 3.0)
# tuple

# %%
t.count('one')
# Out:
# 1

# %%
myset=set()
myset.add(1)
myset.add(3)
myset.add(2)
myset.add(2)
myset
# Out:
# {1, 2, 3}

# %%
mylist=[1,2,3,2,45,532,1,3]
set(mylist)
# Out:
# {1, 2, 3, 45, 532}

# %%
True
False
type(False)
1==1
# Out:
# True

# %%
1>4
# Out:
# False

# %%
b = None
b

# %%
# %%writefile myfile.txt
# hello this is a text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('myfiile.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 myfile = open('myfiile.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfiile.txt'

# %%
pwd
# Out:
# 'E:\\TESTING--\\PLAYWRIGHT WITH PYTHON AND PYTEST\\PYTHON'

# %%
myfile.read()
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.readlines()
# Out:
# []

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
     contents=my_new_file.read()

# %%
contents
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt',mode='r') as file:
    contents = myfile.read()
    contents
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 with open('myfile.txt',mode='r') as file:
# ----> 2     contents = myfile.read()
#       3     contents
#
# ValueError: I/O operation on closed file.

# %%
with open('myfile.txt',mode='r') as file:
    contents = file.read()

# %%
contents
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt',mode='w') as file:
    contents = file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[34], line 2
#       1 with open('myfile.txt',mode='w') as file:
# ----> 2     contents = file.read()
#
# UnsupportedOperation: not readable

# %%
with open('myfile.txt',mode='a') as file:
    contents = file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[35], line 2
#       1 with open('myfile.txt',mode='a') as file:
# ----> 2     contents = file.read()
#
# UnsupportedOperation: not readable

# %%
with open('myfile.txt',mode='a') as file:
    contents = file.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 with open('myfile.txt',mode='a') as file:
# ----> 2     contents = file.append()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
with open('myfile.txt',mode='a') as myfile:
    contents = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[37], line 2
#       1 with open('myfile.txt',mode='a') as myfile:
# ----> 2     contents = myfile.read()
#
# UnsupportedOperation: not readable

# %%
with open('myfile.txt',mode='r') as myfile:
    print(myfile.read())

# %%
with open('myfile.txt',mode='a') as myfile:
    print(myfile.write('\n four line '))
# Out:
# 12

# %%
with open('myfile.txt',mode='r') as myfile:
    print(myfile.read())
# Out:
#  four line

# %%
with open('myfile.txt',mode='a') as myfile:
    print(myfile.write('\n one line '))
# Out:
# 11

# %%
with open('myfile.txt',mode='r') as myfile:
    print(myfile.read())}
# Out:
#   Cell In[44], line 2
#     print(myfile.read())}
#                         ^
# SyntaxError: unmatched '}'

# %%
with open('myfile.txt',mode='r') as myfile:
    print(myfile.read())
# Out:
#  four line
#  one line

# %%
with open('myfiles.txt',mode='w') as myfile:
    print(myfile.write('helo))
# Out:
#   Cell In[47], line 2
#     print(myfile.write('helo))
#                        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
with open('myfiles.txt',mode='w') as myfile:
    print(myfile.write('helo'))
# Out:
# 4

# %%
with open('myfiles.txt',mode='r') as myfile:
    print(myfile.read())
# Out:
# helo
